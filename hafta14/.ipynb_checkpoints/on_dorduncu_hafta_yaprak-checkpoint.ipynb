# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
egitimVeri=pd.read_csv("C:/Users/omerk/Documents/GitHub/yapayzeka/hafta14/yaprakveriseti/train.csv")
#testVeri=pd.read_csv("C:/Users/HASAN/Desktop/yapay_zeka/yaprak_veri_seti/test.csv")

# %%
label_encoder=LabelEncoder().fit(egitimVeri.species)
labels=label_encoder.transform(egitimVeri.species)
classes=list(label_encoder.classes_)

# %%
#Eğitim ve test verileri gereksiz bilgilerden arındırılır 
egitimVeri = egitimVeri.drop(["id","species"],axis=1) 
nb_features = 192
nb_classes = len(classes)

# %%
#Verilerin standartlaştırılması 
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler().fit(egitimVeri.values)
eğitimVeri = scaler.transform(egitimVeri.values) 
    
#Eğitim ve doğrulama verilerinin belirlenmesi 
from sklearn.model_selection import train_test_split 
X_train, X_valid, y_train, y_valid = train_test_split(egitimVeri, labels, test_size = 0.3)

# %%
#Çıktı değerlerinin kategorileştirilmesi 
from tensorflow.keras.utils import to_categorical 
y_train= to_categorical(y_train) 
y_valid = to_categorical(y_valid)

print(X_train.size)
print(" --------")
print(X_valid.size)
print("----")
print(y_train.size)
print("----")
print(y_valid.size)


#19.008*7=
#132*144=19.008

#133.056/144=924
#57.024/144=396
# Out:
# 133056
#  --------
# 57024
# ----
# 68607
# ----
# 29403

# %%
#Girdi verilerinin yeniden boyutlandırılması 

X_train = np.array(X_train).reshape(693,192,1)
X_valid = np.array(X_valid).reshape(297,192,1)

# %%
#Modelin oluşturulması 
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Activation, Dropout ,Conv1D
from tensorflow.keras.layers import MaxPooling1D, Flatten, LSTM, BatchNormalization 

model = Sequential() 
model.add(Conv1D(512,1,input_shape=(nb_features,1)))
model.add(Activation("relu"))
model.add(MaxPooling1D(2))
model.add(Conv1D(256,1))
model.add(Activation("relu"))
model.add(MaxPooling1D(2))
model.add(LSTM(512))
model.add(Activation("relu"))
model.add(BatchNormalization()) 
model.add((Flatten()))
model.add(Dropout (0.15)) 
model.add(Dense(2048, activation="relu"))
model.add(Dense(1024, activation="relu"))
model.add(Dense (nb_classes, activation="softmax")) 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 192, 512)          1024
#
#  activation (Activation)     (None, 192, 512)          0
#
#  max_pooling1d (MaxPooling1D  (None, 96, 512)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 96, 256)           131328
#
#  activation_1 (Activation)   (None, 96, 256)           0
#
#  max_pooling1d_1 (MaxPooling  (None, 48, 256)          0
#  1D)
#
#  lstm (LSTM)                 (None, 512)               1574912
#
#  activation_2 (Activation)   (None, 512)               0
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 2048)              1050624
#
#  dense_1 (Dense)             (None, 1024)              2098176
#
#  dense_2 (Dense)             (None, 99)                101475
#
# =================================================================
# Total params: 4,959,587
# Trainable params: 4,958,563
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
#Modelin derlenmesi
model.compile(loss="categorical_crossentropy", optimizer = "rmsprop", metrics=["accuracy"]) 
#Modelin eğitilmesi 
score = model.fit(X_train, y_train, epochs = 100, validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/100
# 22/22 [==============================] - 15s 587ms/step - loss: 4.5847 - accuracy: 0.0101 - val_loss: 4.5961 - val_accuracy: 0.0101
# Epoch 2/100
# 22/22 [==============================] - 15s 678ms/step - loss: 4.3931 - accuracy: 0.0274 - val_loss: 4.7052 - val_accuracy: 0.0135
# Epoch 3/100
# 22/22 [==============================] - 15s 707ms/step - loss: 4.1219 - accuracy: 0.0375 - val_loss: 4.6499 - val_accuracy: 0.0269
# Epoch 4/100
# 22/22 [==============================] - 16s 709ms/step - loss: 3.8600 - accuracy: 0.0620 - val_loss: 4.6518 - val_accuracy: 0.0101
# Epoch 5/100
# Epoch 87/100
# 22/22 [==============================] - 13s 608ms/step - loss: 0.2057 - accuracy: 0.9380 - val_loss: 69.8987 - val_accuracy: 0.0168
# Epoch 88/100
# 22/22 [==============================] - 13s 606ms/step - loss: 0.2085 - accuracy: 0.9351 - val_loss: 39.5225 - val_accuracy: 0.0505
# Epoch 89/100
# 22/22 [==============================] - 13s 607ms/step - loss: 0.2126 - accuracy: 0.9264 - val_loss: 76.9688 - val_accuracy: 0.0539
# Epoch 90/100
# 22/22 [==============================] - 14s 621ms/step - loss: 0.2036 - accuracy: 0.9423 - val_loss: 43.8594 - val_accuracy: 0.0438
# Epoch 91/100
# 22/22 [==============================] - 13s 583ms/step - loss: 0.1337 - accuracy: 0.9509 - val_loss: 32.2799 - val_accuracy: 0.0842
# Epoch 92/100
# 22/22 [==============================] - 12s 554ms/step - loss: 0.1471 - accuracy: 0.9567 - val_loss: 40.5675 - val_accuracy: 0.0236
# Epoch 93/100
# 22/22 [==============================] - 12s 554ms/step - loss: 0.0997 - accuracy: 0.9668 - val_loss: 30.0715 - val_accuracy: 0.0741
# Epoch 94/100
# 22/22 [==============================] - 12s 562ms/step - loss: 0.2878 - accuracy: 0.9091 - val_loss: 165.4998 - val_accuracy: 0.0101
# Epoch 95/100
# 22/22 [==============================] - 13s 602ms/step - loss: 0.1405 - accuracy: 0.9538 - val_loss: 90.8868 - val_accuracy: 0.0269
# Epoch 96/100
# 22/22 [==============================] - 14s 640ms/step - loss: 0.2330 - accuracy: 0.9134 - val_loss: 54.0272 - val_accuracy: 0.0438
# Epoch 97/100
# 22/22 [==============================] - 15s 681ms/step - loss: 0.1250 - accuracy: 0.9683 - val_loss: 58.9706 - val_accuracy: 0.0404
# Epoch 98/100
# 22/22 [==============================] - 13s 576ms/step - loss: 0.1906 - accuracy: 0.9452 - val_loss: 52.8154 - val_accuracy: 0.0269
# Epoch 99/100
# 22/22 [==============================] - 14s 618ms/step - loss: 0.0515 - accuracy: 0.9856 - val_loss: 17.1182 - val_accuracy: 0.1549
# Epoch 100/100
# 22/22 [==============================] - 14s 626ms/step - loss: 0.1953 - accuracy: 0.9408 - val_loss: 99.5176 - val_accuracy: 0.0202

# %%
print(("Ortalama Doğrulama Kaybı:", np.mean(model.history.history["val_loss"])))
print(("Ortalama Doğrulama Başarımı: ", np.mean(model.history.history["val_accuracy"])))
# Out:
# ('Ortalama Doğrulama Kaybı:', 46.51413688659668)
# ('Ortalama Doğrulama Başarımı: ', 0.032020201853010806)

# %%
#Eğitim ve doğrulama değerlerinin grafik üzerinde gösterilmesi
import matplotlib.pyplot as plt

plt.plot(model.history.history["accuracy"],color="y") 
plt.plot(model.history.history["val_accuracy"],color="b") 
plt.title("Model Başarımları") 
plt.ylabel("Başarım") 
plt.xlabel("Epok Sayısı") 
plt.legend(["Eğitim","Test"], loc="upper left") 
plt.show() 

plt.plot(model.history.history["loss"],color="g")
plt.plot(model.history.history["val_loss"],color="r") 
plt.title("Model Kayıpları") 
plt.ylabel("Kayıp")
plt.xlabel("Epok Sayısı") 
plt.legend (["Eğitim","Doğrulama"], loc="upper left")
plt.show()
